# %% [markdown]
# # Evaluating Models on FS-Mol
#
# `fs_mol.utils.test_utils.eval_model()` is a utility function that allows to evaluate a model against the full set of FS-Mol testing tasks, following a fixed evaluation scheme.
#
# It requires the following arguments:
# * `test_model_fn: Callable[[FSMolTaskSample, str, int], BinaryEvalMetrics]`:
#   This is the core evaluation function, taking a `FSMolTaskSample` (that is, a sample of datapoints from a single task -- see notebooks/dataset.ipynb), a temporary output folder in which to store scratch data, and the seed used for the sampling.
#   It should return `BinaryEvalMetric` object containing all metrics calculated from the model output and labels of the task sample.
# * `dataset: FSMolDataset`:
#   The actual dataset, which can be the full FS-Mol dataset as released, or a different set created directly through its constructor.
#   This is particularly useful if you are planning to evaluate models on a set of tasks differing from FS-Mol's test set.
#
# The returned results contain a list of evaluation metrics for each task, in a dictionary indexed by task name.
#
# Additionally, it can be optionally further configured using the following optional arguments:
# * `out_dir: Optional[str]`:
#    If provided, a summary of the evaluation results will be written, as one CSV file per task.
# * `seed: int`:
#    A seed value used to make sampling and splitting of tasks deterministic.
#    If set to anything but `0`, results of `eval_model` will be incomparable to the canonical evaluation runs.
# * `num_samples: int`:
#    The number of random splits to draw for the task undergoing evaluation.
# * `train_set_sample_sizes: List[int]`:
#    The sizes of training / support set data to consider. For each of these, `num_samples` samples will be drawn for each test task, and then be used to call `test_model_fn` with, where the passed `FSMolTaskSample` will have the requested number of `train_samples`.
# * `valid_size_or_ratio: Union[int, float]`:
#    Number or ratio of `train_samples` in the drawn samples that will be split out into `validation_samples`. This is useful for models that require an explicit validation set during fine-tuning.
# * `test_size_or_ratio: Optional[Union[int, float, Tuple[int, int]]]`:
#    Number or ratio of `test_samples` that will be drawn from the original task. By default, all available samples will be used, but it may be useful to limit this when not using `eval_model` for full model evaluation.
# * `fold: DataFold`:
#    The fold of FS-Mol on which to perform evaluation, typically will be the test fold.
# * `task_reader_fn: Optional[Callable[[List[RichPath], int], Iterable[FSMolTask]]]`:
#    Callable allowing additional transformations on the data prior to its batching and passing through a model.

# %% [markdown]
# ## Example: Evaluating a Random Forst Model

# %%
# Setting up local details:
import os
import sys

# This should be the location of the checkout of the FS-Mol repository:
FS_MOL_CHECKOUT_PATH = os.path.join(os.environ['HOME'], "Projects", "FS-Mol")
FS_MOL_DATASET_PATH = os.path.join(os.environ['HOME'], "Datasets", "FS-Mol")

os.chdir(FS_MOL_CHECKOUT_PATH)
sys.path.insert(0, FS_MOL_CHECKOUT_PATH)

# %% [markdown]
# We first define a simple implementation of a `test_model_fn` that creates a random forest model, using the scikit-learn default implementation and parameters.

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier

from fs_mol.data.fsmol_task import FSMolTaskSample
from fs_mol.utils.metrics import BinaryEvalMetrics, compute_binary_task_metrics

def test_model_fn(
    task_sample: FSMolTaskSample, temp_out_folder: str, seed: int
) -> BinaryEvalMetrics:
    train_data = task_sample.train_samples
    test_data = task_sample.test_samples

    # get data in to form for sklearn
    X_train = np.array([x.get_fingerprint() for x in train_data])
    X_test = np.array([x.get_fingerprint() for x in test_data])
    y_train = [float(x.bool_label) for x in train_data]
    y_test = [float(x.bool_label) for x in test_data]

    model = RandomForestClassifier()
    model.fit(X_train, y_train)

    # Compute test results:
    y_predicted_true_probs = model.predict_proba(X_test)[:, 1]
    test_metrics = compute_binary_task_metrics(y_predicted_true_probs, y_test)

    return test_metrics

# %% [markdown]
# Given these functions, we can now evaluate these models on the test tasks in FS-Mol as follows, reducing the space of considered samples from each task for speed purposes:

# %%
from fs_mol.data.fsmol_dataset import FSMolDataset, DataFold
from fs_mol.utils.test_utils import eval_model

fsmol_dataset = FSMolDataset.from_directory(FS_MOL_DATASET_PATH)

results = eval_model(
    test_model_fn=test_model_fn,
    dataset=fsmol_dataset,
    # Restrict number of samples to one per task:
    train_set_sample_sizes=[16],
    num_samples=1,
)

results
# Out:
# {'CHEMBL1006005': [FSMolTaskSampleEvalResults(size=171, acc=0.5497076023391813, balanced_acc=0.5537766830870279, f1=0.6315789473684211, prec=0.528, recall=0.7857142857142857, roc_auc=0.5892172961138478, avg_precision=0.5489965911494983, kappa=0.10665581111337274, task_name='CHEMBL1006005', seed=0, num_train=16, num_test=171, fraction_pos_train=0.5, fraction_pos_test=0.49122807017543857)],
#  'CHEMBL1066254': [FSMolTaskSampleEvalResults(size=125, acc=0.704, balanced_acc=0.7074795081967213, f1=0.7375886524822695, prec=0.65, recall=0.8524590163934426, roc_auc=0.8209528688524591, avg_precision=0.8158091691137052, kappa=0.4119516846789574, task_name='CHEMBL1066254', seed=0, num_train=16, num_test=125, fraction_pos_train=0.5, fraction_pos_test=0.488)],
#  'CHEMBL1243967': [FSMolTaskSampleEvalResults(size=192, acc=0.6197916666666666, balanced_acc=0.6197916666666667, f1=0.6866952789699571, prec=0.583941605839416, recall=0.8333333333333334, roc_auc=0.6884223090277778, avg_precision=0.6518864408705871, kappa=0.23958333333333337, task_name='CHEMBL1243967', seed=0, num_train=16, num_test=192, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1243970': [FSMolTaskSampleEvalResults(size=192, acc=0.640625, balanced_acc=0.640625, f1=0.6790697674418605, prec=0.6134453781512605, recall=0.7604166666666666, roc_auc=0.7090386284722222, avg_precision=0.7012035484794302, kappa=0.28125, task_name='CHEMBL1243970', seed=0, num_train=16, num_test=192, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1613926': [FSMolTaskSampleEvalResults(size=119, acc=0.6638655462184874, balanced_acc=0.6644067796610169, f1=0.6825396825396826, prec=0.6417910447761194, recall=0.7288135593220338, roc_auc=0.6680790960451977, avg_precision=0.5659025736356059, kappa=0.32844243792325056, task_name='CHEMBL1613926', seed=0, num_train=16, num_test=119, fraction_pos_train=0.5, fraction_pos_test=0.4957983193277311)],
#  'CHEMBL1613898': [FSMolTaskSampleEvalResults(size=151, acc=0.46357615894039733, balanced_acc=0.46596491228070175, f1=0.6048780487804878, prec=0.47692307692307695, recall=0.8266666666666667, roc_auc=0.4964912280701754, avg_precision=0.5332907662928361, kappa=-0.06774334351811429, task_name='CHEMBL1613898', seed=0, num_train=16, num_test=151, fraction_pos_train=0.5, fraction_pos_test=0.4966887417218543)],
#  'CHEMBL1613907': [FSMolTaskSampleEvalResults(size=133, acc=0.5714285714285714, balanced_acc=0.5778280542986426, f1=0.6627218934911243, prec=0.5384615384615384, recall=0.8615384615384616, roc_auc=0.6281674208144796, avg_precision=0.587156804358796, kappa=0.15362286479848164, task_name='CHEMBL1613907', seed=0, num_train=16, num_test=133, fraction_pos_train=0.5, fraction_pos_test=0.48872180451127817)],
#  'CHEMBL1119333': [FSMolTaskSampleEvalResults(size=401, acc=0.6084788029925187, balanced_acc=0.6090796019900497, f1=0.6841046277665995, prec=0.5723905723905723, recall=0.85, roc_auc=0.6961691542288557, avg_precision=0.6797237806211358, kappa=0.21789631911748253, task_name='CHEMBL1119333', seed=0, num_train=16, num_test=401, fraction_pos_train=0.5, fraction_pos_test=0.49875311720698257)],
#  'CHEMBL1613949': [FSMolTaskSampleEvalResults(size=142, acc=0.6619718309859155, balanced_acc=0.5102040816326531, f1=0.039999999999999994, prec=1.0, recall=0.02040816326530612, roc_auc=0.5460829493087558, avg_precision=0.4364259746699606, kappa=0.0265638389031706, task_name='CHEMBL1613949', seed=0, num_train=16, num_test=142, fraction_pos_train=0.3125, fraction_pos_test=0.34507042253521125)],
#  'CHEMBL1614423': [FSMolTaskSampleEvalResults(size=513, acc=0.6471734892787524, balanced_acc=0.5527576197387518, f1=0.2551440329218107, prec=0.6458333333333334, recall=0.15897435897435896, roc_auc=0.6351072407676182, avg_precision=0.5332016792404028, kappa=0.1235239147056324, task_name='CHEMBL1614423', seed=0, num_train=16, num_test=513, fraction_pos_train=0.375, fraction_pos_test=0.38011695906432746)],
#  'CHEMBL1614433': [FSMolTaskSampleEvalResults(size=399, acc=0.5488721804511278, balanced_acc=0.5027656290198096, f1=0.2741935483870968, prec=0.43037974683544306, recall=0.20118343195266272, roc_auc=0.5108309750450218, avg_precision=0.4540440353676581, kappa=0.005951557093425652, task_name='CHEMBL1614433', seed=0, num_train=16, num_test=399, fraction_pos_train=0.4375, fraction_pos_test=0.42355889724310775)],
#  'CHEMBL1613800': [FSMolTaskSampleEvalResults(size=1866, acc=0.6061093247588425, balanced_acc=0.5047395411605937, f1=0.02390438247011952, prec=0.75, recall=0.012145748987854251, roc_auc=0.5072544609386714, avg_precision=0.41476089571162433, kappa=0.011391797386892999, task_name='CHEMBL1613800', seed=0, num_train=16, num_test=1866, fraction_pos_train=0.375, fraction_pos_test=0.3971061093247588)],
#  'CHEMBL1614292': [FSMolTaskSampleEvalResults(size=1564, acc=0.6489769820971867, balanced_acc=0.500284019924537, f1=0.01081081081081081, prec=0.375, recall=0.005484460694698354, roc_auc=0.546190987220901, avg_precision=0.3938126828547362, kappa=0.0007355097594697879, task_name='CHEMBL1614292', seed=0, num_train=16, num_test=1564, fraction_pos_train=0.375, fraction_pos_test=0.34974424552429667)],
#  'CHEMBL1614503': [FSMolTaskSampleEvalResults(size=118, acc=0.7033898305084746, balanced_acc=0.5343677010343677, f1=0.14634146341463414, prec=0.75, recall=0.08108108108108109, roc_auc=0.6823490156823491, avg_precision=0.5531727306558394, kappa=0.09070893879348307, task_name='CHEMBL1614503', seed=0, num_train=16, num_test=118, fraction_pos_train=0.3125, fraction_pos_test=0.3135593220338983)],
#  'CHEMBL1614466': [FSMolTaskSampleEvalResults(size=545, acc=0.563302752293578, balanced_acc=0.49038408323648236, f1=0.07751937984496124, prec=0.3333333333333333, recall=0.043859649122807015, roc_auc=0.5088826166362278, avg_precision=0.4166849195364937, kappa=-0.021901835657448965, task_name='CHEMBL1614466', seed=0, num_train=16, num_test=545, fraction_pos_train=0.4375, fraction_pos_test=0.41834862385321103)],
#  'CHEMBL1737951': [FSMolTaskSampleEvalResults(size=177, acc=0.7401129943502824, balanced_acc=0.7405814905814906, f1=0.6805555555555556, prec=0.6282051282051282, recall=0.7424242424242424, roc_auc=0.7590772590772591, avg_precision=0.6593455029383959, kappa=0.4640600315955766, task_name='CHEMBL1737951', seed=0, num_train=16, num_test=177, fraction_pos_train=0.375, fraction_pos_test=0.3728813559322034)],
#  'CHEMBL1614508': [FSMolTaskSampleEvalResults(size=153, acc=0.7908496732026143, balanced_acc=0.783179012345679, f1=0.746031746031746, prec=0.8703703703703703, recall=0.6527777777777778, roc_auc=0.8511659807956105, avg_precision=0.8562703135117921, kappa=0.5743348982785602, task_name='CHEMBL1614508', seed=0, num_train=16, num_test=153, fraction_pos_train=0.4375, fraction_pos_test=0.47058823529411764)],
#  'CHEMBL1738362': [FSMolTaskSampleEvalResults(size=123, acc=0.7154471544715447, balanced_acc=0.5394736842105263, f1=0.14634146341463414, prec=1.0, recall=0.07894736842105263, roc_auc=0.718266253869969, avg_precision=0.5598453142688018, kappa=0.1059190031152647, task_name='CHEMBL1738362', seed=0, num_train=16, num_test=123, fraction_pos_train=0.3125, fraction_pos_test=0.3089430894308943)],
#  'CHEMBL1614027': [FSMolTaskSampleEvalResults(size=2977, acc=0.5747396708095398, balanced_acc=0.5749968631890039, f1=0.6309037900874636, prec=0.5565843621399177, recall=0.7281292059219381, roc_auc=0.5673216057222654, avg_precision=0.5239842111727842, kappa=0.149916252062121, task_name='CHEMBL1614027', seed=0, num_train=16, num_test=2977, fraction_pos_train=0.5, fraction_pos_test=0.49916022841787033)],
#  'CHEMBL1738079': [FSMolTaskSampleEvalResults(size=216, acc=0.4861111111111111, balanced_acc=0.4871299871299871, f1=0.497737556561086, prec=0.47413793103448276, recall=0.5238095238095238, roc_auc=0.4385242385242385, avg_precision=0.44539026349817884, kappa=-0.02566735112936347, task_name='CHEMBL1738079', seed=0, num_train=16, num_test=216, fraction_pos_train=0.5, fraction_pos_test=0.4861111111111111)],
#  'CHEMBL1613777': [FSMolTaskSampleEvalResults(size=3578, acc=0.5762996087199553, balanced_acc=0.579333594183622, f1=0.6446319737458978, prec=0.5491214057507987, recall=0.7803632236095346, roc_auc=0.5886720136808893, avg_precision=0.5440095676280695, kappa=0.15767994916495487, task_name='CHEMBL1613777', seed=0, num_train=16, num_test=3578, fraction_pos_train=0.5, fraction_pos_test=0.4924538848518726)],
#  'CHEMBL1614522': [FSMolTaskSampleEvalResults(size=742, acc=0.5512129380053908, balanced_acc=0.5517872711421098, f1=0.6295884315906563, prec=0.5349716446124764, recall=0.7648648648648648, roc_auc=0.5953937808776519, avg_precision=0.5663765362878989, kappa=0.10345503232969744, task_name='CHEMBL1614522', seed=0, num_train=16, num_test=742, fraction_pos_train=0.5, fraction_pos_test=0.49865229110512127)],
#  'CHEMBL1738395': [FSMolTaskSampleEvalResults(size=159, acc=0.4968553459119497, balanced_acc=0.4973892405063291, f1=0.5348837209302325, prec=0.4946236559139785, recall=0.5822784810126582, roc_auc=0.5068037974683544, avg_precision=0.5106224779356842, kappa=-0.005215742057847361, task_name='CHEMBL1738395', seed=0, num_train=16, num_test=159, fraction_pos_train=0.5, fraction_pos_test=0.4968553459119497)],
#  'CHEMBL1614153': [FSMolTaskSampleEvalResults(size=3072, acc=0.6650390625, balanced_acc=0.5, f1=0.0, prec=1.0, recall=0.0, roc_auc=0.5493424416826376, avg_precision=0.36335462412425445, kappa=0.0, task_name='CHEMBL1614153', seed=0, num_train=16, num_test=3072, fraction_pos_train=0.3125, fraction_pos_test=0.3349609375)],
#  'CHEMBL1738502': [FSMolTaskSampleEvalResults(size=688, acc=0.6482558139534884, balanced_acc=0.5028351184078864, f1=0.024193548387096777, prec=0.5, recall=0.012396694214876033, roc_auc=0.5265815513471445, avg_precision=0.3773349454352598, kappa=0.0072978774147388625, task_name='CHEMBL1738502', seed=0, num_train=16, num_test=688, fraction_pos_train=0.375, fraction_pos_test=0.35174418604651164)],
#  'CHEMBL1738485': [FSMolTaskSampleEvalResults(size=286, acc=0.5384615384615384, balanced_acc=0.5384615384615384, f1=0.5147058823529412, prec=0.5426356589147286, recall=0.48951048951048953, roc_auc=0.571935057949044, avg_precision=0.5631707972260399, kappa=0.07692307692307687, task_name='CHEMBL1738485', seed=0, num_train=16, num_test=286, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1738573': [FSMolTaskSampleEvalResults(size=1450, acc=0.5448275862068965, balanced_acc=0.5448275862068965, f1=0.6308724832214766, prec=0.5305738476011289, recall=0.7779310344827586, roc_auc=0.5629326991676575, avg_precision=0.564115672721839, kappa=0.08965517241379306, task_name='CHEMBL1738573', seed=0, num_train=16, num_test=1450, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1738579': [FSMolTaskSampleEvalResults(size=198, acc=0.51010101010101, balanced_acc=0.5018433179723503, f1=0.41212121212121217, prec=0.4722222222222222, recall=0.3655913978494624, roc_auc=0.5237071172555043, avg_precision=0.47915876295885845, kappa=0.0037348272642390157, task_name='CHEMBL1738579', seed=0, num_train=16, num_test=198, fraction_pos_train=0.5, fraction_pos_test=0.4696969696969697)],
#  'CHEMBL1738633': [FSMolTaskSampleEvalResults(size=131, acc=0.6412213740458015, balanced_acc=0.6427738927738927, f1=0.7006369426751592, prec=0.5978260869565217, recall=0.8461538461538461, roc_auc=0.6568764568764569, avg_precision=0.6109024530419221, kappa=0.2846520274195423, task_name='CHEMBL1738633', seed=0, num_train=16, num_test=131, fraction_pos_train=0.5, fraction_pos_test=0.4961832061068702)],
#  'CHEMBL1963705': [FSMolTaskSampleEvalResults(size=675, acc=0.6637037037037037, balanced_acc=0.6286066118971003, f1=0.5010989010989011, prec=0.6745562130177515, recall=0.3986013986013986, roc_auc=0.6851708702608446, avg_precision=0.6396591506569462, kappa=0.2719415367509752, task_name='CHEMBL1963705', seed=0, num_train=16, num_test=675, fraction_pos_train=0.4375, fraction_pos_test=0.4237037037037037)],
#  'CHEMBL1794519': [FSMolTaskSampleEvalResults(size=140, acc=0.7071428571428572, balanced_acc=0.7071428571428572, f1=0.6870229007633588, prec=0.7377049180327869, recall=0.6428571428571429, roc_auc=0.7620408163265306, avg_precision=0.8092487846387709, kappa=0.41428571428571426, task_name='CHEMBL1794519', seed=0, num_train=16, num_test=140, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1963721': [FSMolTaskSampleEvalResults(size=331, acc=0.6858006042296072, balanced_acc=0.5256809500083043, f1=0.11864406779661017, prec=0.7, recall=0.06481481481481481, roc_auc=0.5520677628300946, avg_precision=0.4010150119241192, kappa=0.06704970459103488, task_name='CHEMBL1963721', seed=0, num_train=16, num_test=331, fraction_pos_train=0.3125, fraction_pos_test=0.32628398791540786)],
#  'CHEMBL1794504': [FSMolTaskSampleEvalResults(size=114, acc=0.6754385964912281, balanced_acc=0.6727216748768473, f1=0.7218045112781956, prec=0.64, recall=0.8275862068965517, roc_auc=0.7732450738916256, avg_precision=0.7843392697881284, kappa=0.3472609099350047, task_name='CHEMBL1794504', seed=0, num_train=16, num_test=114, fraction_pos_train=0.5, fraction_pos_test=0.5087719298245614)],
#  'CHEMBL1794324': [FSMolTaskSampleEvalResults(size=2053, acc=0.4875791524598149, balanced_acc=0.49155895103593183, f1=0.5422106179286336, prec=0.478494623655914, recall=0.6255020080321285, roc_auc=0.48270375731877374, avg_precision=0.47026459841266965, kappa=-0.01673375042957148, task_name='CHEMBL1794324', seed=0, num_train=16, num_test=2053, fraction_pos_train=0.5, fraction_pos_test=0.48514369215781783)],
#  'CHEMBL1794557': [FSMolTaskSampleEvalResults(size=836, acc=0.49760765550239233, balanced_acc=0.4976076555023924, f1=0.5270270270270271, prec=0.4978723404255319, recall=0.5598086124401914, roc_auc=0.5070682905611136, avg_precision=0.5146652951274605, kappa=-0.004784688995215225, task_name='CHEMBL1794557', seed=0, num_train=16, num_test=836, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1963773': [FSMolTaskSampleEvalResults(size=507, acc=0.6232741617357002, balanced_acc=0.5979692996482251, f1=0.49604221635883905, prec=0.562874251497006, recall=0.44339622641509435, roc_auc=0.5731371921969938, avg_precision=0.5404393658324016, kappa=0.20196959083604593, task_name='CHEMBL1963773', seed=0, num_train=16, num_test=507, fraction_pos_train=0.4375, fraction_pos_test=0.4181459566074951)],
#  'CHEMBL1963715': [FSMolTaskSampleEvalResults(size=875, acc=0.6137142857142858, balanced_acc=0.5022240756185711, f1=0.08648648648648649, prec=0.4, recall=0.048484848484848485, roc_auc=0.6341395607450653, avg_precision=0.48986701499591456, kappa=0.005380864301328336, task_name='CHEMBL1963715', seed=0, num_train=16, num_test=875, fraction_pos_train=0.375, fraction_pos_test=0.37714285714285717)],
#  'CHEMBL1963741': [FSMolTaskSampleEvalResults(size=911, acc=0.5477497255762898, balanced_acc=0.5109099756690998, f1=0.210727969348659, prec=0.4954954954954955, recall=0.13381995133819952, roc_auc=0.5344306569343066, avg_precision=0.5087473618518407, kappa=0.023335935467082902, task_name='CHEMBL1963741', seed=0, num_train=16, num_test=911, fraction_pos_train=0.4375, fraction_pos_test=0.45115257958287597)],
#  'CHEMBL1963701': [FSMolTaskSampleEvalResults(size=904, acc=0.5221238938053098, balanced_acc=0.5221238938053098, f1=0.6288659793814433, prec=0.5140449438202247, recall=0.8097345132743363, roc_auc=0.5180441890516094, avg_precision=0.5115388442609502, kappa=0.04424778761061943, task_name='CHEMBL1963701', seed=0, num_train=16, num_test=904, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1963825': [FSMolTaskSampleEvalResults(size=390, acc=0.6282051282051282, balanced_acc=0.6051961486432721, f1=0.4649446494464945, prec=0.6702127659574468, recall=0.3559322033898305, roc_auc=0.6776875944935147, avg_precision=0.6174507948569499, kappa=0.2190736597895434, task_name='CHEMBL1963825', seed=0, num_train=16, num_test=390, fraction_pos_train=0.4375, fraction_pos_test=0.45384615384615384)],
#  'CHEMBL1963723': [FSMolTaskSampleEvalResults(size=840, acc=0.4976190476190476, balanced_acc=0.47403031462997985, f1=0.27241379310344827, prec=0.4010152284263959, recall=0.206266318537859, roc_auc=0.48653952728373834, avg_precision=0.4659924196830985, kappa=-0.05406514460389311, task_name='CHEMBL1963723', seed=0, num_train=16, num_test=840, fraction_pos_train=0.4375, fraction_pos_test=0.45595238095238094)],
#  'CHEMBL1963810': [FSMolTaskSampleEvalResults(size=654, acc=0.6116207951070336, balanced_acc=0.6017699115044247, f1=0.45258620689655177, prec=0.7046979865771812, recall=0.3333333333333333, roc_auc=0.6109800065552277, avg_precision=0.6122038080853953, kappa=0.20740889181529298, task_name='CHEMBL1963810', seed=0, num_train=16, num_test=654, fraction_pos_train=0.5, fraction_pos_test=0.481651376146789)],
#  'CHEMBL1963731': [FSMolTaskSampleEvalResults(size=624, acc=0.6073717948717948, balanced_acc=0.4968305136082385, f1=0.008097165991902836, prec=0.2, recall=0.004132231404958678, roc_auc=0.6990664618579897, avg_precision=0.5671022459970931, kappa=-0.007725367152688012, task_name='CHEMBL1963731', seed=0, num_train=16, num_test=624, fraction_pos_train=0.375, fraction_pos_test=0.38782051282051283)],
#  'CHEMBL1963824': [FSMolTaskSampleEvalResults(size=407, acc=0.6117936117936118, balanced_acc=0.586036036036036, f1=0.4148148148148148, prec=0.6588235294117647, recall=0.3027027027027027, roc_auc=0.6249208668127587, avg_precision=0.6049520270714359, kappa=0.18018867924528315, task_name='CHEMBL1963824', seed=0, num_train=16, num_test=407, fraction_pos_train=0.4375, fraction_pos_test=0.45454545454545453)],
#  'CHEMBL1963756': [FSMolTaskSampleEvalResults(size=746, acc=0.5938337801608579, balanced_acc=0.5292892591279689, f1=0.21705426356589147, prec=0.56, recall=0.1346153846153846, roc_auc=0.610990488006617, avg_precision=0.5282470680303306, kappa=0.06558027631024133, task_name='CHEMBL1963756', seed=0, num_train=16, num_test=746, fraction_pos_train=0.4375, fraction_pos_test=0.41823056300268097)],
#  'CHEMBL1964005': [FSMolTaskSampleEvalResults(size=149, acc=0.6375838926174496, balanced_acc=0.6362162162162162, f1=0.5423728813559323, prec=0.7272727272727273, recall=0.43243243243243246, roc_auc=0.5835135135135134, avg_precision=0.6435014076957779, kappa=0.273170731707317, task_name='CHEMBL1964005', seed=0, num_train=16, num_test=149, fraction_pos_train=0.5, fraction_pos_test=0.4966442953020134)],
#  'CHEMBL1963799': [FSMolTaskSampleEvalResults(size=345, acc=0.6115942028985507, balanced_acc=0.5122550753342293, f1=0.11842105263157895, prec=0.5, recall=0.06716417910447761, roc_auc=0.5969441890075688, avg_precision=0.48173202812660815, kappa=0.029107862903225756, task_name='CHEMBL1963799', seed=0, num_train=16, num_test=345, fraction_pos_train=0.375, fraction_pos_test=0.3884057971014493)],
#  'CHEMBL1963831': [FSMolTaskSampleEvalResults(size=374, acc=0.6764705882352942, balanced_acc=0.5852883601867188, f1=0.30057803468208094, prec=0.9285714285714286, recall=0.1793103448275862, roc_auc=0.6631380816142147, avg_precision=0.6252661303319565, kappa=0.200205012194691, task_name='CHEMBL1963831', seed=0, num_train=16, num_test=374, fraction_pos_train=0.375, fraction_pos_test=0.3877005347593583)],
#  'CHEMBL1963819': [FSMolTaskSampleEvalResults(size=715, acc=0.6559440559440559, balanced_acc=0.5144731182795699, f1=0.08208955223880596, prec=0.6111111111111112, recall=0.044, roc_auc=0.6047956989247312, avg_precision=0.4494951154450343, kappa=0.03685248056072721, task_name='CHEMBL1963819', seed=0, num_train=16, num_test=715, fraction_pos_train=0.375, fraction_pos_test=0.34965034965034963)],
#  'CHEMBL1963969': [FSMolTaskSampleEvalResults(size=224, acc=0.53125, balanced_acc=0.53125, f1=0.49760765550239233, prec=0.5360824742268041, recall=0.4642857142857143, roc_auc=0.5096460459183674, avg_precision=0.4976434816372762, kappa=0.0625, task_name='CHEMBL1963969', seed=0, num_train=16, num_test=224, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL1963818': [FSMolTaskSampleEvalResults(size=594, acc=0.6599326599326599, balanced_acc=0.633061883654606, f1=0.49246231155778886, prec=0.7480916030534351, recall=0.36704119850187267, roc_auc=0.6680410954197162, avg_precision=0.6762005207712278, kappa=0.2791695202393396, task_name='CHEMBL1963818', seed=0, num_train=16, num_test=594, fraction_pos_train=0.4375, fraction_pos_test=0.4494949494949495)],
#  'CHEMBL2218957': [FSMolTaskSampleEvalResults(size=141, acc=0.6028368794326241, balanced_acc=0.6046277665995976, f1=0.6818181818181818, prec=0.5660377358490566, recall=0.8571428571428571, roc_auc=0.7086519114688128, avg_precision=0.6419350928085825, kappa=0.2085004009623096, task_name='CHEMBL2218957', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL1963827': [FSMolTaskSampleEvalResults(size=597, acc=0.5996649916247906, balanced_acc=0.5994264613450659, f1=0.5857885615251299, prec=0.6014234875444839, recall=0.5709459459459459, roc_auc=0.643502514142049, avg_precision=0.6046275408102384, kappa=0.19893665399709182, task_name='CHEMBL1963827', seed=0, num_train=16, num_test=597, fraction_pos_train=0.5, fraction_pos_test=0.49581239530988275)],
#  'CHEMBL1964106': [FSMolTaskSampleEvalResults(size=300, acc=0.66, balanced_acc=0.5, f1=0.0, prec=1.0, recall=0.0, roc_auc=0.5112893642305407, avg_precision=0.36392098500259207, kappa=0.0, task_name='CHEMBL1964106', seed=0, num_train=16, num_test=300, fraction_pos_train=0.3125, fraction_pos_test=0.34)],
#  'CHEMBL1963838': [FSMolTaskSampleEvalResults(size=224, acc=0.48660714285714285, balanced_acc=0.48660714285714285, f1=0.4888888888888889, prec=0.48672566371681414, recall=0.49107142857142855, roc_auc=0.485530931122449, avg_precision=0.5046263454472011, kappa=-0.02678571428571419, task_name='CHEMBL1963838', seed=0, num_train=16, num_test=224, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL2218959': [FSMolTaskSampleEvalResults(size=141, acc=0.5602836879432624, balanced_acc=0.5608651911468813, f1=0.5921052631578948, prec=0.5487804878048781, recall=0.6428571428571429, roc_auc=0.6093561368209255, avg_precision=0.6109589851193906, kappa=0.12158360128617374, task_name='CHEMBL2218959', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL1963910': [FSMolTaskSampleEvalResults(size=184, acc=0.5434782608695652, balanced_acc=0.5434782608695652, f1=0.5670103092783505, prec=0.5392156862745098, recall=0.5978260869565217, roc_auc=0.5532844990548205, avg_precision=0.5787593006041513, kappa=0.08695652173913049, task_name='CHEMBL1963910', seed=0, num_train=16, num_test=184, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL2219028': [FSMolTaskSampleEvalResults(size=141, acc=0.524822695035461, balanced_acc=0.5261569416498995, f1=0.5988023952095808, prec=0.5154639175257731, recall=0.7142857142857143, roc_auc=0.5088531187122736, avg_precision=0.4949879247424333, kappa=0.052172168154911214, task_name='CHEMBL2219028', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2218946': [FSMolTaskSampleEvalResults(size=141, acc=0.6312056737588653, balanced_acc=0.6340579710144927, f1=0.6708860759493671, prec=0.5955056179775281, recall=0.7681159420289855, roc_auc=0.688707729468599, avg_precision=0.6676660691222498, kappa=0.2665066026410564, task_name='CHEMBL2218946', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2218994': [FSMolTaskSampleEvalResults(size=141, acc=0.5319148936170213, balanced_acc=0.5215812827753126, f1=0.3888888888888889, prec=0.5121951219512195, recall=0.31343283582089554, roc_auc=0.5410447761194029, avg_precision=0.497094375973371, kappa=0.043969591123895646, task_name='CHEMBL2218994', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL1964115': [FSMolTaskSampleEvalResults(size=324, acc=0.6049382716049383, balanced_acc=0.5539971949509116, f1=0.3118279569892473, prec=0.6041666666666666, recall=0.21014492753623187, roc_auc=0.5589839488857722, avg_precision=0.5066769194743468, kappa=0.1179173047473201, task_name='CHEMBL1964115', seed=0, num_train=16, num_test=324, fraction_pos_train=0.4375, fraction_pos_test=0.42592592592592593)],
#  'CHEMBL2219026': [FSMolTaskSampleEvalResults(size=141, acc=0.49645390070921985, balanced_acc=0.4921212121212122, f1=0.4409448818897638, prec=0.45901639344262296, recall=0.42424242424242425, roc_auc=0.5784848484848485, avg_precision=0.5200394643141516, kappa=-0.015829528158295192, task_name='CHEMBL2219026', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.46808510638297873)],
#  'CHEMB
seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219252': [FSMolTaskSampleEvalResults(size=141, acc=0.46808510638297873, balanced_acc=0.47022132796780686, f1=0.5901639344262295, prec=0.4778761061946903, recall=0.7714285714285715, roc_auc=0.44818913480885314, avg_precision=0.4734840441990567, kappa=-0.05930081137934495, task_name='CHEMBL2219252', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219198': [FSMolTaskSampleEvalResults(size=141, acc=0.6028368794326241, balanced_acc=0.6033199195171026, f1=0.6266666666666667, prec=0.5875, recall=0.6714285714285714, roc_auc=0.6725352112676056, avg_precision=0.6957232918254339, kappa=0.20643216080402016, task_name='CHEMBL2219198', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219232': [FSMolTaskSampleEvalResults(size=141, acc=0.475177304964539, balanced_acc=0.47484909456740443, f1=0.4477611940298507, prec=0.46875, recall=0.42857142857142855, roc_auc=0.46559356136820923, avg_precision=0.481753079266957, kappa=-0.05033219247030418, task_name='CHEMBL2219232', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219208': [FSMolTaskSampleEvalResults(size=141, acc=0.49645390070921985, balanced_acc=0.4920330778539733, f1=0.432, prec=0.46551724137931033, recall=0.40298507462686567, roc_auc=0.5222872125857201, avg_precision=0.5235182567235434, kappa=-0.016035725159849745, task_name='CHEMBL2219208', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2219236': [FSMolTaskSampleEvalResults(size=141, acc=0.5531914893617021, balanced_acc=0.5529175050301811, f1=0.5333333333333333, prec=0.5538461538461539, recall=0.5142857142857142, roc_auc=0.585010060362173, avg_precision=0.5627110245792442, kappa=0.10588827377956711, task_name='CHEMBL2219236', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219283': [FSMolTaskSampleEvalResults(size=141, acc=0.5319148936170213, balanced_acc=0.5136363636363637, f1=0.3125, prec=0.5, recall=0.22727272727272727, roc_auc=0.5087878787878788, avg_precision=0.4804328404840136, kappa=0.02819548872180455, task_name='CHEMBL2219283', seed=0, num_train=16, num_test=141, fraction_pos_train=0.4375, fraction_pos_test=0.46808510638297873)],
#  'CHEMBL2219286': [FSMolTaskSampleEvalResults(size=141, acc=0.6028368794326241, balanced_acc=0.6029589371980677, f1=0.6, prec=0.5915492957746479, recall=0.6086956521739131, roc_auc=0.6639492753623188, avg_precision=0.6088273428172067, kappa=0.2057936028968015, task_name='CHEMBL2219286', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL2219225': [FSMolTaskSampleEvalResults(size=141, acc=0.5177304964539007, balanced_acc=0.5196177062374245, f1=0.6179775280898876, prec=0.5092592592592593, recall=0.7857142857142857, roc_auc=0.5319919517102616, avg_precision=0.5528573819554352, kappa=0.03908598917618766, task_name='CHEMBL2219225', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219270': [FSMolTaskSampleEvalResults(size=141, acc=0.5106382978723404, balanced_acc=0.5112812248186946, f1=0.5106382978723404, prec=0.4931506849315068, recall=0.5294117647058824, roc_auc=0.46414182111200647, avg_precision=0.4730747227925462, kappa=0.022505777152617368, task_name='CHEMBL2219270', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL2219242': [FSMolTaskSampleEvalResults(size=141, acc=0.5886524822695035, balanced_acc=0.5548182931808902, f1=0.3695652173913043, prec=0.5666666666666667, recall=0.27419354838709675, roc_auc=0.5694160881992649, avg_precision=0.5302165616368139, kappa=0.11608300907911806, task_name='CHEMBL2219242', seed=0, num_train=16, num_test=141, fraction_pos_train=0.4375, fraction_pos_test=0.4397163120567376)],
#  'CHEMBL2219272': [FSMolTaskSampleEvalResults(size=141, acc=0.5957446808510638, balanced_acc=0.5971830985915493, f1=0.6627218934911243, prec=0.5656565656565656, recall=0.8, roc_auc=0.6668008048289739, avg_precision=0.6471405041407615, kappa=0.19380078242551912, task_name='CHEMBL2219272', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219335': [FSMolTaskSampleEvalResults(size=141, acc=0.5602836879432624, balanced_acc=0.5584913271480436, f1=0.5303030303030304, prec=0.5384615384615384, recall=0.5223880597014925, roc_auc=0.5762404195240015, avg_precision=0.5346248336524637, kappa=0.11714805089880831, task_name='CHEMBL2219335', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2
seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL3431933': [FSMolTaskSampleEvalResults(size=460, acc=0.558695652173913, balanced_acc=0.558695652173913, f1=0.5333333333333333, prec=0.5658536585365853, recall=0.5043478260869565, roc_auc=0.5835538752362949, avg_precision=0.583397804539078, kappa=0.11739130434782608, task_name='CHEMBL3431933', seed=0, num_train=16, num_test=460, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL2219352': [FSMolTaskSampleEvalResults(size=141, acc=0.46808510638297873, balanced_acc=0.4737107171635777, f1=0.5341614906832298, prec=0.46236559139784944, recall=0.6323529411764706, roc_auc=0.49959709911361805, avg_precision=0.5282239627271486, kappa=-0.05192479856759191, task_name='CHEMBL2219352', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48226950354609927)],
#  'CHEMBL2219389': [FSMolTaskSampleEvalResults(size=141, acc=0.5602836879432624, balanced_acc=0.5603621730382293, f1=0.5633802816901409, prec=0.5555555555555556, recall=0.5714285714285714, roc_auc=0.6211267605633803, avg_precision=0.5851929651023138, kappa=0.12070006035003022, task_name='CHEMBL2219389', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.49645390070921985)],
#  'CHEMBL2219359': [FSMolTaskSampleEvalResults(size=141, acc=0.5602836879432624, balanced_acc=0.5634328358208955, f1=0.5753424657534246, prec=0.5316455696202531, recall=0.6268656716417911, roc_auc=0.5689794271883825, avg_precision=0.5255406942983933, kappa=0.12580000000000002, task_name='CHEMBL2219359', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL2219399': [FSMolTaskSampleEvalResults(size=141, acc=0.44680851063829785, balanced_acc=0.4290909090909091, f1=0.20408163265306123, prec=0.3125, recall=0.15151515151515152, roc_auc=0.4338383838383838, avg_precision=0.42717121973321837, kappa=-0.14634146341463405, task_name='CHEMBL2219399', seed=0, num_train=16, num_test=141, fraction_pos_train=0.4375, fraction_pos_test=0.46808510638297873)],
#  'CHEMBL2219408': [FSMolTaskSampleEvalResults(size=141, acc=0.5177304964539007, balanced_acc=0.5066666666666667, f1=0.3928571428571428, prec=0.4782608695652174, recall=0.3333333333333333, roc_auc=0.5015151515151515, avg_precision=0.4790621091071381, kappa=0.013580246913580285, task_name='CHEMBL2219408', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.46808510638297873)],
#  'CHEMBL3707783': [FSMolTaskSampleEvalResults(size=146, acc=0.863013698630137, balanced_acc=0.863013698630137, f1=0.8734177215189873, prec=0.8117647058823529, recall=0.9452054794520548, roc_auc=0.915087258397448, avg_precision=0.8861646598145415, kappa=0.726027397260274, task_name='CHEMBL3707783', seed=0, num_train=16, num_test=146, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL2219375': [FSMolTaskSampleEvalResults(size=141, acc=0.6028368794326241, balanced_acc=0.6038647342995169, f1=0.6164383561643835, prec=0.5844155844155844, recall=0.6521739130434783, roc_auc=0.6627415458937198, avg_precision=0.637378246563148, kappa=0.20722891566265067, task_name='CHEMBL2219375', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.48936170212765956)],
#  'CHEMBL3214944': [FSMolTaskSampleEvalResults(size=562, acc=0.5409252669039146, balanced_acc=0.5409321175278622, f1=0.5409252669039145, prec=0.5390070921985816, recall=0.5428571428571428, roc_auc=0.5616957953394123, avg_precision=0.5114628504794451, kappa=0.08186216154606007, task_name='CHEMBL3214944', seed=0, num_train=16, num_test=562, fraction_pos_train=0.5, fraction_pos_test=0.498220640569395)],
#  'CHEMBL2219404': [FSMolTaskSampleEvalResults(size=141, acc=0.5531914893617021, balanced_acc=0.5439693424768052, f1=0.4324324324324324, prec=0.5454545454545454, recall=0.3582089552238806, roc_auc=0.5481040742234773, avg_precision=0.5721345036809548, kappa=0.0893900563813429, task_name='CHEMBL2219404', seed=0, num_train=16, num_test=141, fraction_pos_train=0.5, fraction_pos_test=0.475177304964539)],
#  'CHEMBL3431930': [FSMolTaskSampleEvalResults(size=458, acc=0.8187772925764192, balanced_acc=0.8187772925764192, f1=0.8134831460674158, prec=0.8379629629629629, recall=0.7903930131004366, roc_auc=0.8558093857859309, avg_precision=0.8746475173546118, kappa=0.6375545851528384, task_name='CHEMBL3431930', seed=0, num_train=16, num_test=458, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL3705334': [FSMolTaskSampleEvalResults(size=127, acc=0.6299212598425197, balanced_acc=0.6302083333333333, f1=0.6412213740458016, prec=0.6176470588235294, recall=0.6666666666666666, roc_auc=0.722470238095238, avg_precision=0.7034041548151624, kappa=0.26025529805428194, task_name='CHEMBL3705334', seed=0, num_train=16, num_test=127, fraction_pos_train=0.5, fraction_pos_test=0.49606299212598426)],
#  'CHEMBL3888461': [FSMolTaskSampleEvalResults(size=157, acc=0.6050955414012739, balanced_acc=0.6054852320675106, f1=0.6265060240963856, prec=0.5909090909090909, recall=0.6666666666666666, roc_auc=0.6358325219084713, avg_precision=0.6127152184740692, kappa=0.21079941624777032, task_name='CHEMBL3888461', seed=0, num_train=16, num_test=157, fraction_pos_train=0.5, fraction_pos_test=0.4968152866242038)],
#  'CHEMBL2354305': [FSMolTaskSampleEvalResults(size=158, acc=0.6075949367088608, balanced_acc=0.6075949367088607, f1=0.6265060240963854, prec=0.5977011494252874, recall=0.6582278481012658, roc_auc=0.6688831917961865, avg_precision=0.6928522525653226, kappa=0.21518987341772156, task_name='CHEMBL2354305', seed=0, num_train=16, num_test=158, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL3705476': [FSMolTaskSampleEvalResults(size=648, acc=0.5617283950617284, balanced_acc=0.5623148368659204, f1=0.6311688311688312, prec=0.5436241610738255, recall=0.7523219814241486, roc_auc=0.6276684924982139, avg_precision=0.6142193961370472, kappa=0.12448263066251819, task_name='CHEMBL3705476', seed=0, num_train=16, num_test=648, fraction_pos_train=0.5, fraction_pos_test=0.4984567901234568)],
#  'CHEMBL3431932': [FSMolTaskSampleEvalResults(size=443, acc=0.7110609480812641, balanced_acc=0.7110900493253434, f1=0.7142857142857143, prec=0.7048458149779736, recall=0.7239819004524887, roc_auc=0.7371692959928253, avg_precision=0.7234559111855943, kappa=0.42215428513196784, task_name='CHEMBL3431932', seed=0, num_train=16, num_test=443, fraction_pos_train=0.5, fraction_pos_test=0.49887133182844245)],
#  'CHEMBL3706128': [FSMolTaskSampleEvalResults(size=201, acc=0.7910447761194029, balanced_acc=0.7523243801652892, f1=0.6818181818181818, prec=0.8653846153846154, recall=0.5625, roc_auc=0.7326446280991736, avg_precision=0.720509086546364, kappa=0.5364594772677356, task_name='CHEMBL3706128', seed=0, num_train=16, num_test=201, fraction_pos_train=0.375, fraction_pos_test=0.39800995024875624)],
#  'CHEMBL3707557': [FSMolTaskSampleEvalResults(size=124, acc=0.7338709677419355, balanced_acc=0.7338709677419355, f1=0.7692307692307693, prec=0.6790123456790124, recall=0.8870967741935484, roc_auc=0.7709417273673258, avg_precision=0.7093142729400551, kappa=0.467741935483871, task_name='CHEMBL3707557', seed=0, num_train=16, num_test=124, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL819742': [FSMolTaskSampleEvalResults(size=142, acc=0.7464788732394366, balanced_acc=0.7464788732394366, f1=0.6949152542372881, prec=0.8723404255319149, recall=0.5774647887323944, roc_auc=0.9177742511406467, avg_precision=0.9117061688375999, kappa=0.49295774647887325, task_name='CHEMBL819742', seed=0, num_train=16, num_test=142, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL3705469': [FSMolTaskSampleEvalResults(size=139, acc=0.60431654676259, balanced_acc=0.6064182194616977, f1=0.6927374301675977, prec=0.5636363636363636, recall=0.8985507246376812, roc_auc=0.6128364389233956, avg_precision=0.5764611531353878, kappa=0.21193691372023504, task_name='CHEMBL3705469', seed=0, num_train=16, num_test=139, fraction_pos_train=0.5, fraction_pos_test=0.49640287769784175)],
#  'CHEMBL3887333': [FSMolTaskSampleEvalResults(size=490, acc=0.789795918367347, balanced_acc=0.789795918367347, f1=0.7685393258426968, prec=0.855, recall=0.6979591836734694, roc_auc=0.8543773427738443, avg_precision=0.8711768488473148, kappa=0.5795918367346939, task_name='CHEMBL3887333', seed=0, num_train=16, num_test=490, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL3706356': [FSMolTaskSampleEvalResults(size=277, acc=0.6931407942238267, balanced_acc=0.6930194974455219, f1=0.6816479400749064, prec=0.7054263565891473, recall=0.6594202898550725, roc_auc=0.783964133041393, avg_precision=0.7717959989667917, kappa=0.3861295789336462, task_name='CHEMBL3706356', seed=0, num_train=16, num_test=277, fraction_pos_train=0.5, fraction_pos_test=0.4981949458483754)],
#  'CHEMBL3887295': [FSMolTaskSampleEvalResults(size=223, acc=0.6502242152466368, balanced_acc=0.6503780566280566, f1=0.6608695652173913, prec=0.6386554621848739, recall=0.6846846846846847, roc_auc=0.6944176319176318, avg_precision=0.67353840548416, kappa=0.30065937600514636, task_name='CHEMBL3887295', seed=0, num_train=16, num_test=223, fraction_pos_train=0.5, fraction_pos_test=0.4977578475336323)],
#  'CHEMBL3887759': [FSMolTaskSampleEvalResults(size=431, acc=0.5939675174013921, balanced_acc=0.5940353143841516, f1=0.6049661399548534, prec=0.5877192982456141, recall=0.6232558139534884, roc_auc=0.5996447028423773, avg_precision=0.5868927292211369, kappa=0.18804430904373848, task_name='CHEMBL3887759', seed=0, num_train=16, num_test=431, fraction_pos_train=0.5, fraction_pos_test=0.4988399071925754)],
#  'CHEMBL3707738': [FSMolTaskSampleEvalResults(size=130, acc=0.5230769230769231, balanced_acc=0.5260416666666666, f1=0.5974025974025974, prec=0.5111111111111111, recall=0.71875, roc_auc=0.431936553030303, avg_precision=0.47744056295168313, kappa=0.051764705882352935, task_name='CHEMBL3707738', seed=0, num_train=16, num_test=130, fraction_pos_train=0.5, fraction_pos_test=0.49230769230769234)],
#  'CHEMBL641707': [FSMolTaskSampleEvalResults(size=148, acc=0.7432432432432432, balanced_acc=0.6867495260164314, f1=0.5681818181818181, prec=0.6097560975609756, recall=0.5319148936170213, roc_auc=0.7873393722350959, avg_precision=0.6151325813801983, kappa=0.38669574700109044, task_name='CHEMBL641707', seed=0, num_train=16, num_test=148, fraction_pos_train=0.3125, fraction_pos_test=0.31756756756756754)],
#  'CHEMBL3887334': [FSMolTaskSampleEvalResults(size=210, acc=0.6095238095238096, balanced_acc=0.6095238095238096, f1=0.6306306306306306, prec=0.5982905982905983, recall=0.6666666666666666, roc_auc=0.628344671201814, avg_precision=0.6369062177939478, kappa=0.21904761904761905, task_name='CHEMBL3887334', seed=0, num_train=16, num_test=210, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL4005586': [FSMolTaskSampleEvalResults(size=232, acc=0.5818965517241379, balanced_acc=0.584132292827945, f1=0.6666666666666666, prec=0.5511363636363636, recall=0.8434782608695652, roc_auc=0.5893719806763286, avg_precision=0.5747742233076679, kappa=0.16750517904705542, task_name='CHEMBL4005586', seed=0, num_train=16, num_test=232, fraction_pos_train=0.5, fraction_pos_test=0.4956896551724138)],
#  'CHEMBL663407': [FSMolTaskSampleEvalResults(size=124, acc=0.6290322580645161, balanced_acc=0.6290322580645161, f1=0.6617647058823529, prec=0.6081081081081081, recall=0.7258064516129032, roc_auc=0.6735171696149843, avg_precision=0.6344854053245113, kappa=0.25806451612903225, task_name='CHEMBL663407', seed=0, num_train=16, num_test=124, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL3888181': [FSMolTaskSampleEvalResults(size=203, acc=0.5024630541871922, balanced_acc=0.5035915356241507, f1=0.5943775100401606, prec=0.5, recall=0.7326732673267327, roc_auc=0.5421277421859834, avg_precision=0.5828002605222331, kappa=0.007166723161105892, task_name='CHEMBL3888181', seed=0, num_train=16, num_test=203, fraction_pos_train=0.5, fraction_pos_test=0.4975369458128079)],
#  'CHEMBL4133035': [FSMolTaskSampleEvalResults(size=182, acc=0.6593406593406593, balanced_acc=0.6593406593406593, f1=0.6702127659574467, prec=0.6494845360824743, recall=0.6923076923076923, roc_auc=0.6767902427243087, avg_precision=0.6117858123717557, kappa=0.31868131868131866, task_name='CHEMBL4133035', seed=0, num_train=16, num_test=182, fraction_pos_train=0.5, fraction_pos_test=0.5)],
#  'CHEMBL915809': [FSMolTaskSampleEvalResults(size=139, acc=0.7194244604316546, balanced_acc=0.7084199584199584, f1=0.6422018348623854, prec=0.7954545454545454, recall=0.5384615384615384, roc_auc=0.8343035343035344, avg_precision=0.8043054028257484, kappa=0.4251935107623793, task_name='CHEMBL915809', seed=0, num_train=16, num_test=139, fraction_pos_train=0.4375, fraction_pos_test=0.4676258992805755)],
#  'CHEMBL657032': [FSMolTaskSampleEvalResults(size=139, acc=0.6906474820143885, balanced_acc=0.6891304347826087, f1=0.6055045871559632, prec=0.825, recall=0.4782608695652174, roc_auc=0.8350931677018634, avg_precision=0.8273621254420569, kappa=0.37939985463607107, task_name='CHEMBL657032', seed=0, num_train=16, num_test=139, fraction_pos_train=0.5, fraction_pos_test=0.49640287769784175)],
#  'CHEMBL924949': [FSMolTaskSampleEvalResults(size=126, acc=0.8253968253968254, balanced_acc=0.8240927419354839, f1=0.8070175438596492, prec=0.8846153846153846, recall=0.7419354838709677, roc_auc=0.8718497983870969, avg_precision=0.8915495219860068, kappa=0.6498231430015159, task_name='CHEMBL924949', seed=0, num_train=16, num_test=126, fraction_pos_train=0.5, fraction_pos_test=0.49206349206349204)]}
